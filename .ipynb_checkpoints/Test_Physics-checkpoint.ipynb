# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(t) :
    return min(1.5*25*t+1, 25)/25

def g(t):
    return min(1.5*25*t+1, 25)/25


N = 15
ts = range(N)


decc = np.zeros(N)
decc[0] = 1.
for i in range(N-1):
    decc[i+1] = g(decc[i])

    
acc = np.zeros(N)
for i in range(N-1):
    acc[i+1] = f(acc[i])

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(ts,25*acc,label="v(t)")
plt.plot(ts,[int(25*ac) for ac in acc], label="v(t) entier")

plt.legend()

plt.subplot(122)
plt.plot(ts,25*decc,label="v(t)")
plt.plot(ts,[int(25*dec) for dec in decc], label="v(t) entier")
plt.legend()
plt.show()

# %%
[int(ac) for ac in acc]
# Out:
# [0, 1, 2, 4, 8, 13, 15, 15, 15, 15]

# %%
def h(t) :
    return min(int((t+1)**2 *15/49),15)
a = [0,1,2,3,4,5,6,8,9,10]

plt.plot(a, [h(t) for t in a])

# %%
[h(t) for t in a]
# Out:
# [0, 1, 2, 4, 7, 11, 15, 15, 15, 15]

# %%
8**3
# Out:
# 512

# %%
plt.plot([1,2,4,8,13,20,25,25,25,25,25])
